# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
# DATA IN PANDAS
data = pd.read_csv("test.csv")
from sklearn.metrics import r2_score
np.random.randn(data.shape[0],1)
msk=np.random.rand(len(data))<=0.7
train=data[msk]
test=data[~msk]
X_train = train[["temp"]]
Y_train = train["acs"]
reg = linear_model.LinearRegression()
reg.fit(X_train, Y_train)
X_test = test[["temp"]]
Y_test = reg.predict(X_test)
z=test["acs"]
print(Y_test)
import matplotlib.pyplot as plt
print(r2_score(z, Y_test) * 100, "%")
sns.regplot(x = test[["temp"]], y = Y_test, data = data);
plt.show()
# fig = plt.figure();
# fig.savefig("Plot_of_temp_vs_ac_sales.png")
#save the figure
# Out:
# [ 78.61458062  80.97952636  73.44133124 151.00330204  72.70032028
#  148.6024904   70.49008526 131.17718418 145.6560028  143.42648261
#  131.96733469  61.5292683  119.29734508  89.44180676  87.12665299
#   55.06473347 110.67680442  69.74446359 122.31231365 139.17567355
#   72.68158951 101.35414198 106.66160143 104.5834519  113.0751485
#  142.74327941 137.82566754 124.48670443  73.03591139  68.32151719
#   94.32148775 151.08643067  65.5517462  149.02170733 101.47931575
#  128.52198229 121.6052322  128.28302429  67.82311404  84.58574313
#  150.50767045  67.8545071  117.52780772  53.3339934  138.914605
#  132.69443495  66.20378028  74.53613283 111.97896645  70.52811538
#  154.36000359  89.26027062 113.52033216 110.95114697 134.81566402
#  123.56180893  74.92955902 133.20415591  96.82480246  96.95575892
#   93.08479201 142.43141361  68.15989714 141.0372528  143.34205141
#   91.85425642 119.12203718 118.12501735  93.68784144 125.1227554
# ...

# %%
#save figure
sns_pp = sns.pairplot(data)
sns_pp.savefig("TempvsAc_sales_Plot.png")
